# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image1=cv2.imread("/content/ChatGPT Image Mar 6, 2026, 04_20_11 PM.png")
plt.imshow(image1)

# %%
image2=cv2.imread("/content/Radiant star in the darkness.png")
plt.imshow(image2)

# %%
add_img=cv2.add(image1,image2)
plt.imshow(add_img)

# %%
addition_by_weigth=cv2.addWeighted(image1,0.5,image2,0.4,0)
plt.imshow(addition_by_weigth)

# %%
addition_by_weigth=cv2.addWeighted(image1,1,image2,1,0)
plt.imshow(addition_by_weigth)

# %%
addition_by_weigth=cv2.addWeighted(image1,0.2,image2,0.6,0)
plt.imshow(addition_by_weigth)

# %%
addition_by_weigth=cv2.addWeighted(image1,0.8,image2,0.5,0)
plt.imshow(addition_by_weigth)
